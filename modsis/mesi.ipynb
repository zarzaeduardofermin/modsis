# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
y = [6, 8, 17, 16, 38, 47, 53, 73, 60, 41, 58, 41, 54, 45, 51, 30, 38, 9, 4]

# %%
plt.figure(figsize=(15,6))
plt.plot(x,y, marker='o',linestyle='--',color='b')
plt.xlabel("Años")
plt.ylabel("Goles")
plt.title("Goles de messi por año jugando al futbol con los pies profesionalmente")
plt.xticks(x)
plt.show()
